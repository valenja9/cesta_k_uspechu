# %% [markdown]
# <a href="https://colab.research.google.com/github/valenja9/cesta_k_uspechu/blob/main/test_it.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 1) Podepiste si tento sesit...
# - 2) Vysledek tohoto testu poslete na kubavalen@seznam.cz nebo dejte zdílet do teamsů
# - 3) Pro splneni testu je treba ziskat alespon 12 bodu

# %%
jmena = ""

# %% [markdown]
# # #Prvni priklad

# %% [markdown]
# - 1) Vytvorte program, ktery do jednotlivych krabicek ulozi infromace:
#      - Nezapomen, ze cislo neni text!
#     - Jmeno
#     - prijmeni
#     - vek
#     - pocet sourozencu
#     - Vsechny informace vypis pomoci printu.
#
# 4 body

# %%
#Programuj zde

# %% [markdown]
# - Vytvor program, ktery odecte dve cisla. Cisla jsou zadana pomoci input
#   - cislo1
#   - cislo2
#   - vysledek
#   - vysledek vypis pomoci print
#
# 4 body

# %%
#Zde programuj

# %% [markdown]
# - Mame spoustu jmen v nasem listu.
#   - Vypis po jednom vsechna jmena, ktera jsou v nasledujicim listu
#   - kolik jmen je v listu?
#
# 4 body

# %%
#Zde programuj
list_jmen = ['Karina',
 'Karin',
 'Karína',
 'Radmila',
 'Diana',
 'Dalemil',
 'Dalimil',
 'Melichar',
 'Baltazar',
 'Kašpar',
 'Vilma',
 'Wilhelmina',
 'Čestmír',
 'Vladan',
 'Břetislav',
 'Bohdana',
 'Pravoslav',
 'Edita',
 'Radovan',
 'Alice',
 'Česlav',
 'Ctirad',
 'Drahoslav',
 'Vladislav',
 'Doubravka',
 'Ilona',
 'Běla',
 'Slavomír',
 'Zdenko',
 'Zdenek',
 'Zdeněk',
 'Milena',
 'Miloš',
 'Zora',
 'Ingrid',
 'Otilie',
 'Otýlie',
 'Zdislava',
 'Zdeslava',
 'Robin',
 'Marika',
 'Hynek',
 'Nela',
 'Blažej',
 'Jarmila',
 'Dobromila',
 'Vanda',
 'Wanda',
 'Veronika',
 'Milada',
 'Apolena',
 'Mojmír',
 'Božena',
 'Slavěna',
 'Věnceslav',
 'Valentin',
 'Valentýn',
 'Valentýna',
 'Jiřina',
 'Jorga',
 'Ljuba',
 'Miloslav',
 'Gisela',
 'Gizela',
 'Patrik',
 'Oldřich',
 'Eleonora',
 'Lenka',
 'Petr',
 'Svatopluk',
 'Matej',
 'Matěj',
 'Matyáš',
 'Lily',
 'Liliana',
 'Lilian',
 'Dorotea',
 'Dorota',
 'Alexis',
 'Alexander',
 'Alexandr',
 'Lumír',
 'Horymír',
 'Rufin',
 'Bedřich',
 'Anežka',
 'Agnes',
 'Ines',
 'Kamil',
 'Stella',
 'Stela',
 'Kazimír',
 'Mirek',
 'Miroslav',
 'Thomas',
 'Tom',
 'Tomáš',
 'Gabriela',
 'Františka',
 'Francesca',
 'Viktorie',
 'Anděla',
 'Angelina',
 'Andělína',
 'Gregor',
 'Řehoř',
 'Rosita',
 'Růžena',
 'Rozálie',
 'Matylda',
 'Rút',
 'Rut',
 'Ida',
 'Herbert',
 'Elena',
 'Vlastimil',
 'Eduard',
 'Edvard',
 'Josef',
 'Jozef',
 'Světlana',
 'Radomil',
 'Radek',
 'Leona',
 'Ivona',
 'Yvona',
 'Gabriel',
 'Marian',
 'Marián',
 'Marius',
 'Emanuel',
 'Ditta',
 'Dita',
 'Sonja',
 'Soňa',
 'Sonia',
 'Tatiana',
 'Taťána',
 'Arnošt',
 'Kvido',
 'Quido',
 'Hugo',
 'Erika',
 'Richard',
 'Ivanka',
 'Ivana',
 'Miroslava',
 'Mirka',
 'Vendula',
 'Vendulka',
 'Hermína',
 'Herman',
 'Heřman',
 'Emma',
 'Ema',
 'Dušana',
 'Dušan',
 'Darja',
 'Daria',
 'Darya',
 'Izabela',
 'Isabel',
 'Julius',
 'Július',
 'Julian',
 'Aleš',
 'Vincent',
 'Vincenc',
 'Anastazia',
 'Anastázie',
 'Irini',
 'Irena',
 'Rudolf',
 'Rolf',
 'Valerie',
 'Valérie',
 'Valeria',
 'Rostislava',
 'Marcela',
 'Alexandra',
 'Evžénie',
 'Evženie',
 'Vojtěch',
 'Jiří',
 'George',
 'Juraj',
 'Marek',
 'Ota',
 'Oto',
 'Otto',
 'Jaroslav',
 'Vlastislav',
 'Robert',
 'Blahoslav',
 'Zikmund',
 'Alex',
 'Alexej',
 'Květoslav',
 'Klaudie',
 'Klaudia',
 'Claudia',
 'Radoslav',
 'Stanislav',
 'Stibor',
 'Ctibor',
 'Blažena',
 'Svatava',
 'Pankrác',
 'Servác',
 'Bonifác',
 'Žofie',
 'Přemysl',
 'Anetta',
 'Aneta',
 'Nataša',
 'Ivo',
 'Ivoš',
 'Zbyšek',
 'Monika',
 'Emil',
 'Vladimír',
 'Jana',
 'Viola',
 'Filip',
 'Valdemar',
 'Waldemar',
 'Vilém',
 'Maximilian',
 'Maxmilián',
 'Maxmilian',
 'Ferdinand',
 'Kamila',
 'Laura',
 'Jarmil',
 'Tamara',
 'Dalibor',
 'Dobroslav',
 'Norbert',
 'Iveta',
 'Yveta',
 'Medard',
 'Stanislava',
 'Otta',
 'Bruno',
 'Antonina',
 'Antonie',
 'Antonín',
 'Antonin',
 'Roland',
 'Vít',
 'Vítek',
 'Zbyněk',
 'Adolf',
 'Milan',
 'Leoš',
 'Květa',
 'Kveta',
 'Alois',
 'Alojz',
 'Aloys',
 'Pavla',
 'Zdena',
 'Zdeňka',
 'Zdenka',
 'Jan',
 'Ivan',
 'Adriana',
 'Ladislav',
 'Lubomír',
 'Lubomil',
 'Pavel',
 'Petr',
 'Šárka',
 'Jaroslava',
 'Patricie',
 'Radomír',
 'Prokop',
 'Metoděj',
 'Cyril',
 'Bohuslava',
 'Nora',
 'Drahoslava',
 'Amálie',
 'Libuše',
 'Olga',
 'Bořek',
 'Markéta',
 'Margareta',
 'Margit',
 'Karolína',
 'Karolina',
 'Karla',
 'Jindřich',
 'Luboslav',
 'Luboš',
 'Liboslav',
 'Martina',
 'Drahomíra',
 'Čeněk',
 'Ilja',
 'Vítězslav',
 'Magdalena',
 'Magdaléna',
 'Libor',
 'Kristina',
 'Kristen',
 'Kristýna',
 'Jakub',
 'Anna',
 'Věroslav',
 'Victor',
 'Viktor',
 'Martha',
 'Marta',
 'Bořivoj',
 'Ignác',
 'Oskar',
 'Gustav',
 'Miluše',
 'Dominik',
 'Křišťan',
 'Kristián',
 'Milivoj',
 'Oldřiška',
 'Lada',
 'Soběslav',
 'Roman',
 'Vavřinec',
 'Susana',
 'Zuzana',
 'Klára',
 'Clara',
 'Alena',
 'Alan',
 'Hanka',
 'Hannah',
 'Hana',
 'Joachim',
 'Jáchym',
 'Petra',
 'Petronila',
 'Helena',
 'Ludvík',
 'Bernard',
 'Johana',
 'Bohuslav',
 'Božislav',
 'Sandra',
 'Bartoloměj',
 'Bartolomej',
 'Radimír',
 'Radim',
 'Luděk',
 'Otokar',
 'Otakar',
 'Augustin',
 'Augustýn',
 'Evelína',
 'Evelin',
 'Evelina',
 'Vladěna',
 'Paulína',
 'Pavlína',
 'Linda',
 'Samuel',
 'Adela',
 'Adléta',
 'Adéla',
 'Bronislav',
 'Henrieta',
 'Jindřiška',
 'Boris',
 'Boleslav',
 'Regina',
 'Regína',
 'Mariana',
 'Daniela',
 'Irma',
 'Denis',
 'Denisa',
 'Marie',
 'Lubor',
 'Radka',
 'Jolana',
 'Ludmila',
 'Naděžda',
 'Saskie',
 'Bohumír',
 'Bohdan',
 'Evžen',
 'Eugen',
 'Martin',
 'Benedikt',
 'Tibor',
 'Sáva',
 'Leopold',
 'Otomar',
 'Otmar',
 'Mahulena',
 'Romana',
 'Alžběta',
 'Elisabeth',
 'Nikola',
 'Albert',
 'Cecílie',
 'Kliment',
 'Klement',
 'Emílie',
 'Emilia',
 'Katka',
 'Kateřina',
 'Katarína',
 'Artur',
 'Xenie',
 'Renée',
 'René',
 'Zina',
 'Ondřej',
 'Iva',
 'Blanka',
 'Světoslav',
 'Svatoslav',
 'Barbora',
 'Barbara',
 'Bára',
 'Jitka',
 'Mikuláš',
 'Nikolas',
 'Mikoláš',
 'Benjamin',
 'Ambrož',
 'Květoslava',
 'Vratislav',
 'Julia',
 'Julie',
 'Juliana',
 'Dana',
 'Simeona',
 'Simona',
 'Šimona',
 'Lucia',
 'Luciana',
 'Lucie',
 'Lydie',
 'Lýdie',
 'Lydia',
 'Radana',
 'Albína',
 'Dan',
 'Daniel',
 'Miloslav',
 'Ester',
 'Dagmara',
 'Dagmar',
 'Dáša',
 'Natálie',
 'Simeon',
 'Šimon',
 'Simon',
 'Vlasta',
 'Eva',
 'Adam',
 'Štěpán',
 'Štepán',
 'Žaneta',
 'Bohumila',
 'Judita',
 'David',
 'Silvestr',
 'Sylvestr',
 'Silvester']

# %% [markdown]
# # Vyhledavani na internetu
#   - Najdi informace o tom co je to v pythonu: "For cyklus"
#   - Vytvor novy google document
#     - zapis do nej 3 informace
#     - vloz obrazek forcyklu
#     - zdroj tvych informaci
#     - Napis jak by vypadal prikaz pro chytrejsi vyhledavani jen na jedne strance
#     - vysledek sdilej pri odevzdani
#
# 5 bodu

# %% [markdown]
# #Bonusovy ukol
#
# - Jak se jmenuje člověk co napsal python?
# - Jaka je delka slova python?
#
# 2 body
